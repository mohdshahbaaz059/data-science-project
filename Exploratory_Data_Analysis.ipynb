# %% [markdown]
# <a href="https://colab.research.google.com/github/mohdshahbaaz059/data-science-project/blob/main/Exploratory_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***CREATE*** ***A*** ***EXPLORATORY*** ***DATA*** ***ANALYSIS***
#
#
# STEP 1: TAKE DATA FROM ANY SOURCE FROM ANYWHERE HTTP://

# %% [markdown]
# Downloading the Data

# %%
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/00445/Absenteeism_at_work_AAA.zip
# Out:
# --2023-04-27 20:21:40--  https://archive.ics.uci.edu/ml/machine-learning-databases/00445/Absenteeism_at_work_AAA.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 66136 (65K) [application/x-httpd-php]
# Saving to: ‘Absenteeism_at_work_AAA.zip’
#
# Absenteeism_at_work 100%[===================>]  64.59K  --.-KB/s    in 0.1s
#
# 2023-04-27 20:21:41 (507 KB/s) - ‘Absenteeism_at_work_AAA.zip’ saved [66136/66136]

# %% [markdown]
# STEP 2: AFTER TAKING SOURCE CHECK THE FILE TO EXTRACT FILE

# %%
# !unzip /content/Absenteeism_at_work_AAA.zip
# Out:
# Archive:  /content/Absenteeism_at_work_AAA.zip
#   inflating: Absenteeism_at_work.arff
#   inflating: Absenteeism_at_work.csv
#   inflating: Absenteeism_at_work.xls
#   inflating: Attribute Information.docx
#   inflating: UCI_ABS_TEXT.docx

# %% [markdown]
# IMPORT PANDAS AND NUMPY VERY IMPORTANT TO SOLVE AND READ THE EXCEL FILE WE USED PANDAS

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# EXTRACT THE EXCEL WE USED PANDAS THIS CODE FILE (NAME.XLS)

# %%
df = pd.read_excel('Absenteeism_at_work.xls')

# %% [markdown]
# TO SOLVE THE CSV FILE
# USED THIS LINE df = pd.read_csv('Absenteeism_at_work.csv')
#
#
#
# UNDER & ORDER LINE df = pd.read_csv('Absenteeism_at_work.csv',SEP = ';')

# %% [markdown]
# Reading the Data

# %%
df = pd.read_csv('Absenteeism_at_work.csv',sep = ';')
df = df[df['Reason for absence']!=0]
df = df[df['Reason for absence']<=21]

# %% [markdown]
# DF = dATAFRAME
#  USED TOCHECK THE DATA

# %%
df
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 3     7                   7                 7                5        1
# 8    14                  19                 7                2        1
# 10   20                   1                 7                2        1
# 11   20                   1                 7                3        1
# 12   20                  11                 7                4        1
# ..   ..                 ...               ...              ...      ...
# 727   9                   6                 7                2        1
# 729   9                   6                 7                3        1
# 734  13                  13                 7                2        1
# 735  11                  14                 7                3        1
# 736   1                  11                 7                3        1
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# ...

# %% [markdown]
# TOSOLVE FILE.DOCX WE TAKE INFORMATIOM FROM SOURCE FILE

# %%
"""
1 Certa"in infectious and parasitic diseases  
2 Neoplasms  
3 Diseases of the blood and blood-forming organs and certain disorders involving the immune mechanism  
4 Endocrine, nutritional and metabolic diseases  
5 Mental and behavioural disorders  
6 Diseases of the nervous system  
7 Diseases of the eye and adnexa  
8 Diseases of the ear and mastoid process  
9 Diseases of the circulatory system  
10 Diseases of the respiratory system  
11 Diseases of the digestive system  
12 Diseases of the skin and subcutaneous tissue  
13 Diseases of the musculoskeletal system and connective tissue  
14 Diseases of the genitourinary system  
15 Pregnancy, childbirth and the puerperium  
16 Certain conditions originating in the perinatal period  
17 Congenital malformations, deformations and chromosomal abnormalities  
18 Symptoms, signs and abnormal clinical and laboratory findings, not elsewhere classified  
19 Injury, poisoning and certain other consequences of external causes  
20 External causes of morbidity and mortality  
21 Factors influencing health status and contact with health services.
"""
# Out:
# '\n1 Certa"in infectious and parasitic diseases  \n2 Neoplasms  \n3 Diseases of the blood and blood-forming organs and certain disorders involving the immune mechanism  \n4 Endocrine, nutritional and metabolic diseases  \n5 Mental and behavioural disorders  \n6 Diseases of the nervous system  \n7 Diseases of the eye and adnexa  \n8 Diseases of the ear and mastoid process  \n9 Diseases of the circulatory system  \n10 Diseases of the respiratory system  \n11 Diseases of the digestive system  \n12 Diseases of the skin and subcutaneous tissue  \n13 Diseases of the musculoskeletal system and connective tissue  \n14 Diseases of the genitourinary system  \n15 Pregnancy, childbirth and the puerperium  \n16 Certain conditions originating in the perinatal period  \n17 Congenital malformations, deformations and chromosomal abnormalities  \n18 Symptoms, signs and abnormal clinical and laboratory findings, not elsewhere classified  \n19 Injury, poisoning and certain other consequences of external
# ...

# %% [markdown]
# SOURCE FILE WE HAVE TAKEN IMPROTANT POINT TO EXTRACT

# %% [markdown]
# Replaceing the text in spreadsheet/dataframe

# %%
diseases = {
    1: 'infectious',
    2: 'neoplasms',
    3: 'blood_diseases',
    4: 'matabolic-diseases',
    5: 'mental-diseases',
    6: 'nervous system',
    7: 'eye-diseases',
    8: 'ear-diseases',
    9: 'circulatory-diseases',
    10: 'respiratory-diseases',
    11: 'digestive-diseases',
    12: 'skin-diseases',
    13: 'musculoskeletal',
    14: 'genitourinary-system',
    15: 'childbirth',
    16: 'prenatal',
    17: 'chromosomal-abnormalities',
    18: 'lab-findings',
    19: 'injury-poisoning',
    20: 'mortality',
    21: 'contact-health-services',
    }
df['Reason for absence'] = df['Reason for absence'].replace(diseases)

# %% [markdown]
# INSIDE THE IMPORTANT POINT LASTLINE OF 23 IS USED TO REPLACE THE NUMBER COUNVERT THE IMPORTANT NAME AS DISEASES

# %%
df
# Out:
#      ID    Reason for absence  Month of absence  Day of the week  Seasons  \
# 3     7          eye-diseases                 7                5        1
# 8    14      injury-poisoning                 7                2        1
# 10   20            infectious                 7                2        1
# 11   20            infectious                 7                3        1
# 12   20    digestive-diseases                 7                4        1
# ..   ..                   ...               ...              ...      ...
# 727   9        nervous system                 7                2        1
# 729   9        nervous system                 7                3        1
# 734  13       musculoskeletal                 7                2        1
# 735  11  genitourinary-system                 7                3        1
# 736   1    digestive-diseases                 7                3        1
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# ...

# %%
df
# Out:
#      ID    Reason for absence  Month of absence  Day of the week  Seasons  \
# 3     7          eye-diseases                 7                5        1
# 8    14      injury-poisoning                 7                2        1
# 10   20            infectious                 7                2        1
# 11   20            infectious                 7                3        1
# 12   20    digestive-diseases                 7                4        1
# ..   ..                   ...               ...              ...      ...
# 727   9        nervous system                 7                2        1
# 729   9        nervous system                 7                3        1
# 734  13       musculoskeletal                 7                2        1
# 735  11  genitourinary-system                 7                3        1
# 736   1    digestive-diseases                 7                3        1
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# ...

# %% [markdown]
# FIRST LINE USED TO FILTER THE DATA SHOULD BE NOT EQUAL TO 0
# SECOUND LINE USED TO SOME NUMBER AVAILABLE SO WE USED <=21
# LESS THAN EQUAL TO 21
# THIS TWO FILE MOVE CSV LINE

# %%
df
# Out:
#      ID    Reason for absence  Month of absence  Day of the week  Seasons  \
# 3     7          eye-diseases                 7                5        1
# 8    14      injury-poisoning                 7                2        1
# 10   20            infectious                 7                2        1
# 11   20            infectious                 7                3        1
# 12   20    digestive-diseases                 7                4        1
# ..   ..                   ...               ...              ...      ...
# 727   9        nervous system                 7                2        1
# 729   9        nervous system                 7                3        1
# 734  13       musculoskeletal                 7                2        1
# 735  11  genitourinary-system                 7                3        1
# 736   1    digestive-diseases                 7                3        1
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# ...

# %% [markdown]
# **Univariate** **EDA**

# %% [markdown]
# ## **Q/A based Exploring of the Variable**

# %% [markdown]
# Q1: what are  the top 5 Reason For Absence

# %% [markdown]
# COUNT IMPORT THE COUNTER

# %%
from collections import Counter

Counts = dict(Counter(df['Reason for absence']))


keys = list(Counts.keys())
values = list(Counts.values())

table = pd.DataFrame()
table['Reason for absence'] = keys
table['count'] = values
table = table.sort_values(by='count',ascending=False).iloc[0:5]
table
# Out:
#      Reason for absence  count
# 7       musculoskeletal     55
# 1      injury-poisoning     40
# 3    digestive-diseases     26
# 6  respiratory-diseases     25
# 8          lab-findings     21

# %% [markdown]
# Q2: what are the top 5 months in which absenteesim was high?

# %%
df = pd.read_csv('Absenteeism_at_work.csv',sep = ';')

# %%
counts = Counter(df['Month of absence'])
table = pd.DataFrame()
table['month'] = counts.keys()
table['absents'] = counts.values()
table = table.sort_values(by='absents',ascending=False).iloc[0:5]
table
# Out:
#     month  absents
# 8       3       87
# 7       2       72
# 3      10       71
# 0       7       67
# 10      5       64

# %% [markdown]
# **ABSENTEEISM** **WEEK**

# %%
counts = Counter(df['Day of the week'])
table = pd.DataFrame()
table['day'] = counts.keys()
table['absents'] = counts.values()
table = table.sort_values(by='absents',ascending=False).iloc[0:3]
table
# Out:
#    day  absents
# 4    2      161
# 1    4      156
# 0    3      154

# %% [markdown]
# Q3:which day of the week people are most absent?
# (top 3)

# %%
 days = {
    2:'monday',
    3:'Tuesday',
    4:'Wednesday',
    5:'Thusday',
    6:'Friday',
}
df['Day of the week'] = df['Day of the week'].replace(days)
counts = Counter(df['Day of the week'])

table = pd.DataFrame()
table['day'] = counts.keys()
table['absents'] = counts.values()
table = table.sort_values(by='absents',ascending=False).iloc[0:3]
table
# Out:
#          day  absents
# 4     monday      161
# 1  Wednesday      156
# 0    Tuesday      154

# %% [markdown]
# **Distribution based exploration of features**

# %%
col = df['Month of absence'].hist()

# %%
seasons = pd.read_csv('Absenteeism_at_work.csv',sep = ';')

# %%
df['Day of the week'].hist()
# Out:
# <Axes: >

# %%
seasons = {
    1:'summer',
    2:'winter',
    3:'autumn',
    4:'spring',
  }
df['Seasons'] = df['Seasons'].replace(seasons)

# %%
df['Seasons']
# Out:
# 0      summer
# 1      summer
# 2      summer
# 3      summer
# 4      summer
#         ...
# 735    summer
# 736    summer
# 737    summer
# 738    winter
# 739    autumn
# Name: Seasons, Length: 740, dtype: object

# %%
df['Distance from Residence to Work'].hist()
# Out:
# <Axes: >

# %%
df['Transportation expense'].hist()
# Out:
# <Axes: >

# %%
df['Seasons'].hist()
# Out:
# <Axes: >

# %%
df['Transportation expense']
# Out:
# 0      289
# 1      118
# 2      179
# 3      279
# 4      289
#       ...
# 735    289
# 736    235
# 737    118
# 738    231
# 739    179
# Name: Transportation expense, Length: 740, dtype: int64

# %%
df.columns
# Out:
# Index(['ID', 'Reason for absence', 'Month of absence', 'Day of the week',
#        'Seasons', 'Transportation expense', 'Distance from Residence to Work',
#        'Service time', 'Age', 'Work load Average/day ', 'Hit target',
#        'Disciplinary failure', 'Education', 'Son', 'Social drinker',
#        'Social smoker', 'Pet', 'Weight', 'Height', 'Body mass index',
#        'Absenteeism time in hours'],
#       dtype='object')

# %%
df['Transportation expense'].hist()
df['Distance from Residence to Work'].hist()
# Out:
# <Axes: >

# %%
df['Age']
# Out:
# 0      33
# 1      50
# 2      38
# 3      39
# 4      33
#        ..
# 735    33
# 736    37
# 737    40
# 738    39
# 739    53
# Name: Age, Length: 740, dtype: int64

# %%
df['Age'].hist()
# Out:
# <Axes: >

# %%
df['Service time']
# Out:
# 0      13
# 1      18
# 2      18
# 3      14
# 4      13
#        ..
# 735    13
# 736    14
# 737    13
# 738    14
# 739    14
# Name: Service time, Length: 740, dtype: int64

# %%
df['Service time'].hist()
# Out:
# <Axes: >

# %%
df
# Out:
#      ID  Reason for absence  Month of absence Day of the week Seasons  \
# 0    11                  26                 7         Tuesday  summer
# 1    36                   0                 7         Tuesday  summer
# 2     3                  23                 7       Wednesday  summer
# 3     7                   7                 7         Thusday  summer
# 4    11                  23                 7         Thusday  summer
# ..   ..                 ...               ...             ...     ...
# 735  11                  14                 7         Tuesday  summer
# 736   1                  11                 7         Tuesday  summer
# 737   4                   0                 0         Tuesday  summer
# 738   8                   0                 0       Wednesday  winter
# 739  35                   0                 0          Friday  autumn
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# ...

# %%
df
# Out:
#      ID  Reason for absence  Month of absence Day of the week Seasons  \
# 0    11                  26                 7         Tuesday  summer
# 1    36                   0                 7         Tuesday  summer
# 2     3                  23                 7       Wednesday  summer
# 3     7                   7                 7         Thusday  summer
# 4    11                  23                 7         Thusday  summer
# ..   ..                 ...               ...             ...     ...
# 735  11                  14                 7         Tuesday  summer
# 736   1                  11                 7         Tuesday  summer
# 737   4                   0                 0         Tuesday  summer
# 738   8                   0                 0       Wednesday  winter
# 739  35                   0                 0          Friday  autumn
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# ...

# %%
df['Disciplinary failure']
# Out:
# 0      0
# 1      1
# 2      0
# 3      0
# 4      0
#       ..
# 735    0
# 736    0
# 737    0
# 738    0
# 739    0
# Name: Disciplinary failure, Length: 740, dtype: int64

# %%
df['Disciplinary failure'].hist()
# Out:
# <Axes: >

# %%
df['Education']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 735    1
# 736    3
# 737    1
# 738    1
# 739    1
# Name: Education, Length: 740, dtype: int64

# %%
df['Education'].hist()
# Out:
# <Axes: >

# %%
df['Son']
# Out:
# 0      2
# 1      1
# 2      0
# 3      2
# 4      2
#       ..
# 735    2
# 736    1
# 737    1
# 738    2
# 739    1
# Name: Son, Length: 740, dtype: int64

# %%
df['Son'].hist()
# Out:
# <Axes: >

# %%
df['Social drinker']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 735    1
# 736    0
# 737    1
# 738    1
# 739    0
# Name: Social drinker, Length: 740, dtype: int64

# %%
df['Social drinker'].hist()
# Out:
# <Axes: >

# %%
df
# Out:
#      ID  Reason for absence  Month of absence Day of the week Seasons  \
# 0    11                  26                 7         Tuesday  summer
# 1    36                   0                 7         Tuesday  summer
# 2     3                  23                 7       Wednesday  summer
# 3     7                   7                 7         Thusday  summer
# 4    11                  23                 7         Thusday  summer
# ..   ..                 ...               ...             ...     ...
# 735  11                  14                 7         Tuesday  summer
# 736   1                  11                 7         Tuesday  summer
# 737   4                   0                 0         Tuesday  summer
# 738   8                   0                 0       Wednesday  winter
# 739  35                   0                 0          Friday  autumn
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# ...

# %%
df['Body mass index']
# Out:
# 0      30
# 1      31
# 2      31
# 3      24
# 4      30
#        ..
# 735    30
# 736    29
# 737    34
# 738    35
# 739    25
# Name: Body mass index, Length: 740, dtype: int64

# %%
df['Body mass index'].hist()
# Out:
# <Axes: >

# %%
df['Pet']
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 735    1
# 736    1
# 737    8
# 738    2
# 739    1
# Name: Pet, Length: 740, dtype: int64

# %%
df['Pet'].hist()
# Out:
# <Axes: >

# %%
df['Height']
# Out:
# 0      172
# 1      178
# 2      170
# 3      168
# 4      172
#       ...
# 735    172
# 736    172
# 737    170
# 738    170
# 739    175
# Name: Height, Length: 740, dtype: int64

# %%
df['Height'].hist()
# Out:
# <Axes: >

# %%
df['Social smoker']
# Out:
# 0      0
# 1      0
# 2      0
# 3      1
# 4      0
#       ..
# 735    0
# 736    0
# 737    0
# 738    0
# 739    0
# Name: Social smoker, Length: 740, dtype: int64

# %%
df['Social smoker'].hist()
# Out:
# <Axes: >

# %%
df['Hit target']
# Out:
# 0      97
# 1      97
# 2      97
# 3      97
# 4      97
#        ..
# 735    93
# 736    93
# 737    95
# 738    95
# 739    95
# Name: Hit target, Length: 740, dtype: int64

# %%
df['Hit target'].hist()
# Out:
# <Axes: >

# %%
df['Service time']
# Out:
# 0      13
# 1      18
# 2      18
# 3      14
# 4      13
#        ..
# 735    13
# 736    14
# 737    13
# 738    14
# 739    14
# Name: Service time, Length: 740, dtype: int64

# %%
df['Service time'].hist()
# Out:
# <Axes: >

# %%
df['Social smoker']
# Out:
# 0      0
# 1      0
# 2      0
# 3      1
# 4      0
#       ..
# 735    0
# 736    0
# 737    0
# 738    0
# 739    0
# Name: Social smoker, Length: 740, dtype: int64

# %%
df['Social smoker'].hist()
# Out:
# <Axes: >

# %%
df['Weight']
# Out:
# 0       90
# 1       98
# 2       89
# 3       68
# 4       90
#       ...
# 735     90
# 736     88
# 737     98
# 738    100
# 739     77
# Name: Weight, Length: 740, dtype: int64

# %%
df['Weight'].hist()
# Out:
# <Axes: >

# %%
df
# Out:
#      ID  Reason for absence  Month of absence Day of the week Seasons  \
# 0    11                  26                 7         Tuesday  summer
# 1    36                   0                 7         Tuesday  summer
# 2     3                  23                 7       Wednesday  summer
# 3     7                   7                 7         Thusday  summer
# 4    11                  23                 7         Thusday  summer
# ..   ..                 ...               ...             ...     ...
# 735  11                  14                 7         Tuesday  summer
# 736   1                  11                 7         Tuesday  summer
# 737   4                   0                 0         Tuesday  summer
# 738   8                   0                 0       Wednesday  winter
# 739  35                   0                 0          Friday  autumn
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# ...

# %%
df['Age'].max()
# Out:
# 58

# %%
df['Age'].min()
# Out:
# 27

# %%
"""
-1 to 1
"""
# Out:
# '\n-1 to 1\n'

# %% [markdown]
# ***Correlation Analysis***
#
# it is a metric which is  calculated on two column of a data.
#
# Let's assume the two columns are A & B.
# value of corrleation is between -1 to 1
#
#
# -1 means -> A & B are inversly proportional
#
#
#
# 1 means -> A & B are directly proportional
#
#
#
# 0 means -> A & B are doesn't have any correlation

# %%
df.corr()
# Out:
# <ipython-input-63-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                                        ID  Reason for absence  \
# ID                               1.000000           -0.064245
# Reason for absence              -0.064245            1.000000
# Month of absence                -0.000043           -0.083858
# Transportation expense          -0.224163           -0.119381
# Distance from Residence to Work -0.486160            0.161831
# Service time                    -0.272704            0.048425
# Age                              0.040899           -0.078608
# Work load Average/day            0.092457           -0.123472
# Hit target                       0.018789            0.088943
# Disciplinary failure             0.004502           -0.545054
# ...

# %%
df['Distance from Residence to Work'].min()
# Out:
# 5

# %%
df['Distance from Residence to Work'].max()
# Out:
# 52

# %%
social_drinker = df['Social drinker']

# %%
f_col = 'Distance from Residence to Work'
filter = (df[f_col]>=5) & (df[f_col]<10)
df[filter]['Social drinker'].hist()
print(35/25)
print(14/8)
print(12/3)
"""
Distance
5-10: 0(NO)/3(Drink)
10-15: 35(No)/25(Yes)
15-20: 14(No)/8(Yes)
20-25: 12(No)/3(Yes)

"""
# Out:
# 1.4
# 1.75
# 4.0
# '\nDistance\n5-10: 0(NO)/3(Drink)\n10-15: 35(No)/25(Yes)\n15-20: 14(No)/8(Yes)\n20-25: 12(No)/3(Yes)\n\n'

# %%
f_col = 'Social drinker'
filter = (df[f_col]==1)
df[filter]['Education'].hist()
# Out:
# <Axes: >

# %%
import seaborn as sns
sns.boxplot(df['Age'])
# Out:
# <Axes: >

# %% [markdown]
# ***Outlier Detection***

# %%
df.skew()
# Out:
# <ipython-input-76-9e0b1e29546f>:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.skew()
# ID                                 0.016606
# Reason for absence                -0.915312
# Month of absence                   0.069369
# Transportation expense             0.396189
# Distance from Residence to Work    0.312083
# Service time                      -0.004720
# Age                                0.697703
# Work load Average/day              0.961457
# Hit target                        -1.261708
# Disciplinary failure               3.952270
# Education                          2.108953
# Son                                1.086465
# Social drinker                    -0.273327
# Social smoker                      3.290333
# ...

# %%
sns.boxplot(df['Height'])
# Out:
# <Axes: >

# %%
sns.boxplot(df[(df['Height']>165)&(df['Height']<175)]['Height'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-89-709752f36d0f> in <cell line: 1>()
# ----> 1 sns.boxplot(df[(df['Height']>165)&(df['Height']<175)]['Height']).skew()
#
# AttributeError: 'Axes' object has no attribute 'skew'

# %%
df[(df['Height']>165)&(df['Height']<175)]['Height'].skew()
# Out:
# -0.23650541605376532
