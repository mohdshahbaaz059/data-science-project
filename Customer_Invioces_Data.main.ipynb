# %% [markdown]
# <a href="https://colab.research.google.com/github/mohdshahbaaz059/data-science-project/blob/main/Customer_Invioces_Data.main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd


import time, warnings
import datetime as dt

#visualizations
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
# %matplotlib inline
import seaborn as sns

warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("customer_invoices_data.csv", encoding="ISO-8859-1", dtype={'CustomerID': str,'InvoiceID': str})

# %%
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#       InvoiceDate  Price  Customer ID         Country
# 0  12/1/2009 7:45   6.95      13085.0  United Kingdom
# 1  12/1/2009 7:45   6.75      13085.0  United Kingdom
# 2  12/1/2009 7:45   6.75      13085.0  United Kingdom
# 3  12/1/2009 7:45   2.10      13085.0  United Kingdom
# 4  12/1/2009 7:45   1.25      13085.0  United Kingdom

# %%
df[df.Invoice.str.contains('\D').replace(pd.NA,False)]
# Out:
#         Invoice StockCode                       Description  Quantity  \
# 178     C489449     22087          PAPER BUNTING WHITE LACE       -12
# 179     C489449    85206A      CREAM FELT EASTER EGG BASKET        -6
# 180     C489449     21895     POTTING SHED SOW 'N' GROW SET        -4
# 181     C489449     21896                POTTING SHED TWINE        -6
# 182     C489449     22083        PAPER CHAIN KIT RETRO SPOT       -12
# ...         ...       ...                               ...       ...
# 524695  C538123     22956          36 FOIL HEART CAKE CASES        -2
# 524696  C538124         M                            Manual        -4
# 524697  C538124     22699  ROSES REGENCY TEACUP AND SAUCER         -1
# 524698  C538124     22423          REGENCY CAKESTAND 3 TIER        -1
# 525282  C538164    35004B       SET OF 3 BLACK FLYING DUCKS        -1
#
#             InvoiceDate  Price  Customer ID         Country
# 178     12/1/2009 10:33   2.95      16321.0       Australia
# ...

# %%
df
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# 525456  538171     22271                 FELTCRAFT DOLL ROSIE         2
# 525457  538171     22750         FELTCRAFT PRINCESS LOLA DOLL         1
# 525458  538171     22751       FELTCRAFT PRINCESS OLIVIA DOLL         1
# 525459  538171     20970   PINK FLORAL FELTCRAFT SHOULDER BAG         2
# 525460  538171     21931               JUMBO STORAGE BAG SUKI         2
#
#             InvoiceDate  Price  Customer ID         Country
# ...

# %%
df
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# 525456  538171     22271                 FELTCRAFT DOLL ROSIE         2
# 525457  538171     22750         FELTCRAFT PRINCESS LOLA DOLL         1
# 525458  538171     22751       FELTCRAFT PRINCESS OLIVIA DOLL         1
# 525459  538171     20970   PINK FLORAL FELTCRAFT SHOULDER BAG         2
# 525460  538171     21931               JUMBO STORAGE BAG SUKI         2
#
#             InvoiceDate  Price  Customer ID         Country
# ...

# %%
df.shape
# Out:
# (417534, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525461 entries, 0 to 525460
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      525461 non-null  object
#  1   StockCode    525461 non-null  object
#  2   Description  522533 non-null  object
#  3   Quantity     525461 non-null  int64
#  4   InvoiceDate  525461 non-null  object
#  5   Price        525461 non-null  float64
#  6   Customer ID  417534 non-null  float64
#  7   Country      525461 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 32.1+ MB

# %% [markdown]
# Why missing CustID?
# - possibly guest checkout feature on the website
#
#
# What could be possible features that you would collect if you want to segment "guest" customers?
#   - browser, IP, location, cookie

# %% [markdown]
# ### Remove rows where customerID are NA

# %%
df.dropna(subset=['Customer ID'], inplace=True)
df.shape
# Out:
# (417534, 8)

# %%
df
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# 525456  538171     22271                 FELTCRAFT DOLL ROSIE         2
# 525457  538171     22750         FELTCRAFT PRINCESS LOLA DOLL         1
# 525458  538171     22751       FELTCRAFT PRINCESS OLIVIA DOLL         1
# 525459  538171     20970   PINK FLORAL FELTCRAFT SHOULDER BAG         2
# 525460  538171     21931               JUMBO STORAGE BAG SUKI         2
#
#             InvoiceDate  Price  Customer ID         Country
# ...

# %%
import altair as alt
from google.colab import autoviz
df_3617489969645931809 = autoviz.get_registered_df('df_3617489969645931809')

def linked_scatter_plots(
    df, colname_pairs, color='steelblue', deselected_color='lightgray',
    opacity=0.8, deselected_opacity=0.4, width=150, height=150):
  interval = alt.selection_interval()
  scatter = (alt.Chart(df).mark_circle()
             .encode(
                 color=alt.condition(
                     interval, alt.value(color), alt.value(deselected_color)),
                 opacity=alt.condition(
                     interval, alt.value(opacity),
                     alt.value(deselected_opacity)))
             .properties(
                 selection=interval, width=width, height=height))
  return alt.hconcat(*[scatter.encode(x=x, y=y) for x, y in colname_pairs])

chart = linked_scatter_plots(df_3617489969645931809, *[[['index', 'Quantity'], ['Quantity', 'Price'], ['Price', 'Customer ID']]], **{})
chart

# %%
df['Customer ID'].isna().sum()
# Out:
# 0

# %% [markdown]
# ## RFM Analysis
# RFM (Recency, Frequency, Monetary) analysis is a customer segmentation technique that uses past purchase behavior to divide customers into groups. RFM helps divide customers into various categories or clusters to identify customers who are more likely to respond to promotions and also for future personalization services.
#
# **RECENCY (R)**: Days since last purchase
#
# **FREQUENCY (F):** Total number of purchases
#
# **MONETARY VALUE (M):** Total money this customer spent.
#
# We will create those 3 customer attributes for each customer.

# %% [markdown]
# ## Recency
# To calculate recency, we need to choose a date point from which we evaluate how many days ago was the customer's last purchase.

# %% [markdown]
# ### Find out the latest date in the data to use it as for reference

# %%
df.InvoiceDate.max()
# Out:
# '9/9/2010 20:03'

# %%
now = dt.date(2009,12,1)
print(now)
# Out:
# 2009-12-01

# %%
df.Country.nunique()
# Out:
# 37

# %%
df.describe()
# Out:
#             Quantity          Price    Customer ID
# count  417534.000000  417534.000000  417534.000000
# mean       12.758815       3.887547   15360.645478
# std       101.220424      71.131797    1680.811316
# min     -9360.000000       0.000000   12346.000000
# 25%         2.000000       1.250000   13983.000000
# 50%         4.000000       1.950000   15311.000000
# 75%        12.000000       3.750000   16799.000000
# max     19152.000000   25111.090000   18287.000000

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# ### Create a new column called date which contains the date of invoice only

# %%
df['date'] = pd.DatetimeIndex(df.InvoiceDate).date

df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#       InvoiceDate  Price  Customer ID         Country        date
# 0  12/1/2009 7:45   6.95      13085.0  United Kingdom  2009-12-01
# 1  12/1/2009 7:45   6.75      13085.0  United Kingdom  2009-12-01
# 2  12/1/2009 7:45   6.75      13085.0  United Kingdom  2009-12-01
# 3  12/1/2009 7:45   2.10      13085.0  United Kingdom  2009-12-01
# 4  12/1/2009 7:45   1.25      13085.0  United Kingdom  2009-12-01

# %%
recency_df = df.groupby('Customer ID', as_index=False).date.max()
recency_df.columns = ['Customer ID', 'LastPurchaseDate']
recency_df.head()
# Out:
#    Customer ID LastPurchaseDate
# 0      12346.0       2010-10-04
# 1      12347.0       2010-12-07
# 2      12348.0       2010-09-27
# 3      12349.0       2010-10-28
# 4      12351.0       2010-11-29

# %%
recency_df['Recency'] = recency_df.LastPurchaseDate.apply(lambda x: (now-x).days)
recency_df.head()
# Out:
#    Customer ID LastPurchaseDate  Recency
# 0      12346.0       2010-10-04     -307
# 1      12347.0       2010-12-07     -371
# 2      12348.0       2010-09-27     -300
# 3      12349.0       2010-10-28     -331
# 4      12351.0       2010-11-29     -363

# %% [markdown]
# ## Frequency
# Frequency helps us to know how many times a customer purchased from us. To do that we need to check how many invoices are registered by the same customer.

# %% [markdown]
# ### Drop duplicate data from the data

# %%
df
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# 525456  538171     22271                 FELTCRAFT DOLL ROSIE         2
# 525457  538171     22750         FELTCRAFT PRINCESS LOLA DOLL         1
# 525458  538171     22751       FELTCRAFT PRINCESS OLIVIA DOLL         1
# 525459  538171     20970   PINK FLORAL FELTCRAFT SHOULDER BAG         2
# 525460  538171     21931               JUMBO STORAGE BAG SUKI         2
#
#             InvoiceDate  Price  Customer ID         Country        date
# ...

# %%
df = df.copy()
df.drop_duplicates(subset=['Invoice', 'Customer ID'], keep='first', inplace=True)
df.head()
# Out:
#    Invoice StockCode                          Description  Quantity  \
# 0   489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 8   489435     22350                            CAT BOWL         12
# 12  489436    48173C                DOOR MAT BLACK FLOCK         10
# 31  489437     22143    CHRISTMAS CRAFT HEART DECORATIONS         6
# 54  489438     21329              DINOSAURS  WRITING SET         28
#
#        InvoiceDate  Price  Customer ID         Country        date
# 0   12/1/2009 7:45   6.95      13085.0  United Kingdom  2009-12-01
# 8   12/1/2009 7:46   2.55      13085.0  United Kingdom  2009-12-01
# 12  12/1/2009 9:06   5.95      13078.0  United Kingdom  2009-12-01
# 31  12/1/2009 9:08   2.10      15362.0  United Kingdom  2009-12-01
# 54  12/1/2009 9:24   0.98      18102.0  United Kingdom  2009-12-01

# %% [markdown]
# ***Calculate the Fraquency of Purchases***

# %%
frequency_df = df.groupby('Customer ID', as_index=False).Invoice.count()
frequency_df.columns = ['Customer ID', 'Frequency']
frequency_df.head()
# Out:
#    Customer ID  Frequency
# 0      12346.0         15
# 1      12347.0          2
# 2      12348.0          1
# 3      12349.0          4
# 4      12351.0          1

# %% [markdown]
# ## Monetary
#
# **Monetary attribute answers the question: How much money did the customer spent over time?**
#
# ### To do that, first, we will create a new column total cost to have the total price per invoice.

# %%
df['TotalCost'] = df.Quantity * df.Price

# %%
df.head()
# Out:
#    Invoice StockCode                          Description  Quantity  \
# 0   489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 8   489435     22350                            CAT BOWL         12
# 12  489436    48173C                DOOR MAT BLACK FLOCK         10
# 31  489437     22143    CHRISTMAS CRAFT HEART DECORATIONS         6
# 54  489438     21329              DINOSAURS  WRITING SET         28
#
#        InvoiceDate  Price  Customer ID         Country        date  TotalCost
# 0   12/1/2009 7:45   6.95      13085.0  United Kingdom  2009-12-01      83.40
# 8   12/1/2009 7:46   2.55      13085.0  United Kingdom  2009-12-01      30.60
# 12  12/1/2009 9:06   5.95      13078.0  United Kingdom  2009-12-01      59.50
# 31  12/1/2009 9:08   2.10      15362.0  United Kingdom  2009-12-01      12.60
# 54  12/1/2009 9:24   0.98      18102.0  United Kingdom  2009-12-01      27.44

# %%
monetary_df = df.groupby('Customer ID', as_index=False).TotalCost.sum()
monetary_df.columns = ['Customer ID', 'Monetary']
monetary_df.head()
# Out:
#    Customer ID  Monetary
# 0      12346.0    100.06
# 1      12347.0     42.90
# 2      12348.0     13.20
# 3      12349.0    233.90
# 4      12351.0     10.50

# %% [markdown]
# italicised text### Create RFM Table

# %%
rfm_df = (recency_df
 .merge(frequency_df, on='Customer ID')
 .merge(monetary_df, on='Customer ID')
)

rfm_df.set_index('Customer ID', inplace=True)
rfm_df.head()
# Out:
#             LastPurchaseDate  Recency  Frequency  Monetary
# Customer ID
# 12346.0           2010-10-04     -307         15    100.06
# 12347.0           2010-12-07     -371          2     42.90
# 12348.0           2010-09-27     -300          1     13.20
# 12349.0           2010-10-28     -331          4    233.90
# 12351.0           2010-11-29     -363          1     10.50

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'Quantity'}>,
#         <Axes: title={'center': 'Price'}>],
#        [<Axes: title={'center': 'Customer ID'}>,
#         <Axes: title={'center': 'TotalCost'}>]], dtype=object)

# %%
df
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 8       489435     22350                            CAT BOWL         12
# 12      489436    48173C                DOOR MAT BLACK FLOCK         10
# 31      489437     22143    CHRISTMAS CRAFT HEART DECORATIONS         6
# 54      489438     21329              DINOSAURS  WRITING SET         28
# ...        ...       ...                                  ...       ...
# 525303  538167     22086      PAPER CHAIN KIT 50'S CHRISTMAS         40
# 525328  538168     22078             RIBBON REEL LACE DESIGN          5
# 525358  538169     22156        HEART DECORATION WITH PEARLS          2
# 525371  538170     84879        ASSORTED COLOUR BIRD ORNAMENT        16
# 525396  538171     22824       3 TIER SWEETHEART GARDEN SHELF         1
#
#             InvoiceDate  Price  Customer ID         Country        date  \
# ...

# %% [markdown]
# ## Customer segments with RFM Model
#
# **The simplest way to create customers segments from RFM Model is to use Quartiles. We assign a score from 1 to 4 to Recency, Frequency and Monetary. Four is the best/highest value, and one is the lowest/worst value. A final RFM score is calculated simply by combining individual RFM score numbers.**
#
# Note: Quintiles (score from 1-5) offer better granularity, in case the business needs that but it will be more challenging to create segments since we will have 555 possible combinations. So, we will use quartiles.

# %% [markdown]
# *italicised text*### Find RFM quartiles

# %%
quantiles = rfm_df.quantile(q=[0,0.25,0.5,0.75,1])
quantiles
# Out:
#       Recency  Frequency  Monetary
# 0.00   -373.0        1.0 -25111.09
# 0.25   -357.0        1.0     14.14
# 0.50   -322.0        3.0     37.50
# 0.75   -236.0        6.0    107.10
# 1.00      0.0      270.0  43007.77

# %%
rfm_df.Frequency.quantile(q=[0,0.5,0.7,0.8,1])
# Out:
# 0.0     1.0
# 0.5     2.0
# 0.7     3.0
# 0.8     4.0
# 1.0    96.0
# Name: Frequency, dtype: float64

# %% [markdown]
# ## Creation of RFM Segments
#
# We will create two segmentation classes since, high recency is bad, while high frequency and monetary value is good.

# %% [markdown]
# ### Create functions as per the appropriate quaritle values and apply them to create segments

# %%
r_labels = range(4,0,-1)
r_groups = pd.qcut(rfm_df.Recency, q=4, labels=r_labels)
r_groups.head()
# Out:
# Customer ID
# 12346.0    2
# 12347.0    4
# 12348.0    2
# 12349.0    3
# 12351.0    4
# Name: Recency, dtype: category
# Categories (4, int64): [4 < 3 < 2 < 1]

# %%
m_labels = range(1,5)
m_groups = pd.qcut(rfm_df.Monetary, q=4, labels=m_labels)
m_groups.head()
# Out:
# Customer ID
# 12346.0    3
# 12347.0    3
# 12348.0    1
# 12349.0    4
# 12351.0    1
# Name: Monetary, dtype: category
# Categories (4, int64): [1 < 2 < 3 < 4]

# %%
f_labels = range(1,5)
f_groups = pd.qcut(rfm_df.Frequency, q=[0,0.5,0.7,0.8,1], labels=f_labels)

f_groups.head()
# Out:
# Customer ID
# 12346.0    4
# 12347.0    1
# 12348.0    1
# 12349.0    2
# 12351.0    1
# Name: Frequency, dtype: category
# Categories (4, int64): [1 < 2 < 3 < 4]

# %% [markdown]
# <<ToTal sCore (R_Quartile, F_Quartile,M_Quartile)>>

# %%
rfm_df = rfm_df.assign(R=r_groups,F=f_groups,M=m_groups)

# %%
rfm_df
# Out:
#             LastPurchaseDate  Recency  Frequency  Monetary  R  F  M
# Customer ID
# 12346.0           2010-10-04     -307         15    100.06  2  4  3
# 12347.0           2010-12-07     -371          2     42.90  4  1  3
# 12348.0           2010-09-27     -300          1     13.20  2  1  1
# 12349.0           2010-10-28     -331          4    233.90  3  2  4
# 12351.0           2010-11-29     -363          1     10.50  4  1  1
# ...                      ...      ...        ...       ... .. .. ..
# 18283.0           2010-11-22     -356          6     13.94  3  3  1
# 18284.0           2010-10-06     -309          2     25.00  2  1  2
# 18285.0           2010-02-17      -78          1     29.90  1  1  2
# 18286.0           2010-08-20     -262          3      8.00  2  1  1
# 18287.0           2010-11-22     -356          5     75.30  3  2  3
#
# [4383 rows x 7 columns]

# %%
rfm_df['RFM_segment'] = rfm_df.apply(lambda x : '{}{}{}'.format(x.R , x.F, x.M), axis=1)
rfm_df['RFM_score'] = rfm_df.loc[:,['R','F','M']].sum(axis=1)
rfm_df.head()
# Out:
#             LastPurchaseDate  Recency  Frequency  Monetary  R  F  M  \
# Customer ID
# 12346.0           2010-10-04     -307         15    100.06  2  4  3
# 12347.0           2010-12-07     -371          2     42.90  4  1  3
# 12348.0           2010-09-27     -300          1     13.20  2  1  1
# 12349.0           2010-10-28     -331          4    233.90  3  2  4
# 12351.0           2010-11-29     -363          1     10.50  4  1  1
#
#             RFM_segment  RFM_score
# Customer ID
# 12346.0             243          9
# 12347.0             413          8
# 12348.0             211          4
# 12349.0             324          9
# 12351.0             411          6

# %%
df

# %%
rfm_df.loc[rfm_df.RFM_segment == '243'].index.values
# Out:
# array([12346., 12975., 13015., 13152., 13313., 13440., 13503., 13782.,
#        14492., 14745., 14844., 15013., 15015., 15046., 15321., 15339.,
#        15367., 15696., 15751., 16202., 16555., 16631., 16875., 16918.,
#        17092., 17426., 17578., 18009., 18037.])

# %% [markdown]
# Best Customer

# %%
rfm_df.loc[rfm_df.RFM_segment == '413'].index.values
# Out:
# array([12347., 12356., 12358., 12377., 12385., 12808., 12868., 12897.,
#        12967., 13010., 13108., 13277., 13369., 13402., 13602., 13626.,
#        13652., 13891., 13992., 14014., 14083., 14119., 14127., 14170.,
#        14189., 14202., 14332., 14487., 14491., 14506., 14673., 14756.,
#        14865., 14932., 15018., 15084., 15111., 15160., 15180., 15192.,
#        15261., 15269., 15287., 15350., 15392., 15572., 15752., 15922.,
#        15939., 15973., 16122., 16140., 16194., 16203., 16306., 16356.,
#        16421., 16519., 16545., 16596., 16781., 16863., 16935., 17167.,
#        17223., 17341., 17430., 17598., 17633., 17722., 17723., 17756.,
#        18085., 18113., 18193., 18239.])

# %% [markdown]
# Loyal Customer

# %%
rfm_df.loc[rfm_df.F == 2,'RFM_segment'].value_counts()
# Out:
# 223    97
# 323    82
# 423    72
# 324    58
# 224    53
# 222    41
# 322    34
# 424    29
# 123    26
# 121    25
# 422    24
# 421    24
# 221    24
# 321    21
# 124    18
# 122    11
# Name: RFM_segment, dtype: int64

# %% [markdown]
# 3. Big Spenders
# - since Monetary value distribution is skewed, we might consider our big spender to be filtered by RFM_seg = xx3+

# %%
rfm_df.loc[rfm_df.M >= 3,'RFM_segment'].value_counts()
# Out:
# 444    360
# 213    147
# 113    140
# 344    140
# 313    137
# 223     97
# 443     88
# 323     82
# 114     80
# 413     76
# 423     72
# 244     67
# 214     61
# 434     60
# 433     59
# 324     58
# 224     53
# 343     49
# 314     44
# 333     40
# 334     39
# 234     37
# 233     33
# 414     31
# 243     29
# 424     29
# 123     26
# 124     18
# 144     13
# 133     11
# 143      6
# 134      5
# Name: RFM_segment, dtype: int64

# %% [markdown]
# 4. Almost lost customers
# - RFM_seg = <=2 <=2 <=2
# - or if you have periodic data, like for every financial quarter FY Q1, FY Q2, FY Q3 check the customer trend

# %%
rfm_df.query('R<=2 and F<=4 and M<=3').RFM_segment.value_counts()
# Out:
# 111    425
# 112    310
# 212    258
# 211    202
# 213    147
# 113    140
# 223     97
# 222     41
# 233     33
# 243     29
# 123     26
# 121     25
# 221     24
# 232     17
# 241     13
# 131     12
# 122     11
# 133     11
# 231     10
# 143      6
# 242      4
# 141      3
# 132      2
# 142      2
# Name: RFM_segment, dtype: int64

# %% [markdown]
# 5. Lost customers
# - customers with the lowest score RFM_seg = 111

# %%
rfm_df.loc[rfm_df.RFM_segment=='411','RFM_segment'].value_counts()
# Out:
# 411    99
# Name: RFM_segment, dtype: int64

# %%
rfm_df.hist()
# Out:
# array([[<Axes: title={'center': 'Recency'}>,
#         <Axes: title={'center': 'Frequency'}>],
#        [<Axes: title={'center': 'Monetary'}>,
#         <Axes: title={'center': 'RFM_score'}>]], dtype=object)
