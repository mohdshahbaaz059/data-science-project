# %% [markdown]
# <a href="https://colab.research.google.com/github/mohdshahbaaz059/data-science-project/blob/main/AI_Mathematical_Olympiad_Progress_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
# !unzip /content/ai-mathematical-olympiad-prize.zip
# Out:
# Archive:  /content/ai-mathematical-olympiad-prize.zip
#   inflating: AIMO Prize - Note on Language and Notation.pdf
#   inflating: aimo/__init__.py
#   inflating: aimo/competition.cpython-310-x86_64-linux-gnu.so
#   inflating: sample_submission.csv
#   inflating: test.csv
#   inflating: train.csv

# %%
df = pd.read_csv('sample_submission.csv')
df1 = pd.read_csv('test.csv')
df2 = pd.read_csv('train.csv')

# %%
df2
# Out:
#        id                                            problem  answer
# 0  229ee8  Let $k, l > 0$ be parameters. The parabola $y ...      52
# 1  246d26  Each of the three-digits numbers $111$ to $999...     250
# 2  2fc4ad  Let the `sparkle' operation on positive intege...     702
# 3  430b63  What is the minimum value of $5x^2+5y^2-8xy$ w...     800
# 4  5277ed  There exists a unique increasing geometric seq...     211
# 5  739bc9  For how many positive integers $m$ does the eq...     199
# 6  82e2a0  Suppose that we roll four 6-sided fair dice wi...     185
# 7  8ee6f3  The points $\left(x, y\right)$ satisfying $((\...     320
# 8  bedda4  Let $ABCD$ be a unit square. Let $P$ be the po...     480
# 9  d7e9c9  A function $f: \mathbb N \to \mathbb N$ satisf...     199

# %%
df1
# Out:
#    row_id      id                 problem
# 0       0  000aaa          What is $1-1$?
# 1       1  111bbb    What is $0\times10$?
# 2       2  222ccc  Solve $4+x=4$ for $x$.

# %%
df
# Out:
#    row_id      id  answer
# 0       0  000aaa       0
# 1       1  111bbb       0
# 2       2  222ccc       0

# %%
# Define your model
class Model:
    def predict(self, x):
        return 0

model = Model()

# %%
# Set up the evaluation API
import aimo

env = aimo.make_env()
iter_test = env.iter_test()

# %%
# Iterate through the test set and use the model make predictions
for test, sample_submission in iter_test:
    sample_submission['answer'] = model.predict(test['problem'])
    env.predict(sample_submission)
    print(test)
    print(sample_submission, '\n')
# Out:
# This version of the API is not optimized and should not be used to estimate the runtime of your code on the hidden test set.
#        id         problem
# 0  000aaa  What is $1-1$?
#        id  answer
# 0  000aaa       0
#
#        id               problem
# 0  111bbb  What is $0\times10$?
#        id  answer
# 0  111bbb       0
#
#        id                 problem
# 0  222ccc  Solve $4+x=4$ for $x$.
#        id  answer
# 0  222ccc       0
